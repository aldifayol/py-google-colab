# %% [markdown]
# <a href="https://colab.research.google.com/github/aldifayol/py-google-colab/blob/main/house_prices_adv_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# Memisahkan fitur (X) dan target (y)
X = df_lencoder.drop(columns=['SalePrice'])
y = df_lencoder['SalePrice']

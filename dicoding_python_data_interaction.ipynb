# %% [markdown]
# <a href="https://colab.research.google.com/github/aldifayol/py-google-colab/blob/main/dicoding_python_data_interaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dictionary Exercise

# data_diri = {
#     'firstName': 'Aldi',
#     'lastName': 'Fayol',
#     'age': 37,
#     'isMarried': True,
# }

# data_diri['Job'] = None
# print(data_diri)

# data_diri['lastName'] = 'Lalawi'
# print(data_diri)

# del data_diri['isMarried']
# print(data_diri)


# toConvert = input("please enter the value you want to convert: ")

# converted = int(toConvert)
# print(type(converted))


# umur = 30
# name = 'Evans'
# isRaining = F11alse
# isWearingRaincoat = False

# name = 'thegreatpython'

# print(name[3:7])

# address = 'Jakarta'

# myList = ['Evans', 30, address]

# print(id(myList[0]))
# print(id(myList[1]))
# print(id(myList[2]))

# myList[0] = 'Aldi'

# print(myList)

# print(id(myList[0]))
# print(id(myList[1]))
# print(id(myList[2]))

# isMarried = True

# myTuple = ("Aldi", 37, "Software Developer", isMarried)

# mySet = { 2, 3, 2, 1, 7, 6, 6 }

# mySet_2 = { 4, 5, 5, 3, 7, 9}

# print(mySet_2.intersection(mySet))

# print(mySet)
# print(type(mySet))


# -----------------------------------------------------------------------------

# Exercise

# Declare a variable called name and assign your full name in it

name_name = 'aldi alfarnando'

# Define a slicing method to only take your last name

print(name_name[5:])

# Declare a list that assign a skill you mastered the most

mySkills = ["html", 'css', 'js']

# Try to modify the value of some indexes

mySkills[2] = 'css3'

print(mySkills)

# Declare a tuple and assign the skill you want to master in the future

# Also try to modify it

# Declare two sets and assign some numbers into it

set_1 = { 1, 2, 3, 5, 7, 11, 13, 17, 19, 23, 27, 29, 31}

set_2 = { 0, 1, 1, 2, 3, 5, 8, 13, 21 }

# Try to print those sets

print(set_1)
print(set_2)

# Implement the union method and analyze the output

print(set_1.union(set_2))

# Also do the intersection method

print(set_1.intersection(set_2))
# Out:
# alfarnando
# ['html', 'css', 'css3']
# {1, 2, 3, 5, 7, 11, 13, 17, 19, 23, 27, 29, 31}
# {0, 1, 2, 3, 5, 8, 13, 21}
# {0, 1, 2, 3, 5, 7, 8, 11, 13, 17, 19, 21, 23, 27, 29, 31}
# {1, 2, 3, 5, 13}

# %%
print('\n'.join("%i Byte = %i Bit = largest number: %i" % (j, j*8, 256**j-1) for j in (1 << i for i in range(8))))
# Out:
# 1 Byte = 8 Bit = largest number: 255
# 2 Byte = 16 Bit = largest number: 65535
# 4 Byte = 32 Bit = largest number: 4294967295
# 8 Byte = 64 Bit = largest number: 18446744073709551615
# 16 Byte = 128 Bit = largest number: 340282366920938463463374607431768211455
# 32 Byte = 256 Bit = largest number: 115792089237316195423570985008687907853269984665640564039457584007913129639935
# 64 Byte = 512 Bit = largest number: 13407807929942597099574024998205846127479365820592393377723561443721764030073546976801874298166903427690031858186486050853753882811946569946433649006084095
# 128 Byte = 1024 Bit = largest number: 

# %%
print(r'Dicoding\nIndonesia')
# Out:
# Dicoding\nIndonesia

# %%
import pandas as pd

data = {
    'name': ['aldi', 'alyn'],
    'age': [37, 30],
    'occupation': ['engineer', 'architect'],
}

df = pd.DataFrame(data)

print(df)
# Out:
#    name  age occupation
# 0  aldi   37   engineer
# 1  alyn   30  architect

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 4, 7, 8, 11, 12]
y = [2, 4, 7, 3, 13, 9, 20]

# Membuat plot garis
plt.plot(x, y)

# Menambahkan judul dan label sumbu
plt.title("Contoh Plot Garis")
plt.xlabel("Sumbu X")
plt.ylabel("Sumbu Y")

# Menampilkan plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Contoh data
tips = sns.load_dataset('tips')  # Memuat dataset tips dari Seaborn

# Contoh plot histogram
sns.histplot(tips['total_bill'], kde=True)
plt.title('Histogram Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# Pengambilan konten
url = "http://python.org/"
page = urlopen(url)
html = page.read().decode("utf-8")

# Membuat objek BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Mencetak judul halaman
print(soup.title)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2053138465.py in <cell line: 0>()
#       5 url = "http://python.org/"
#       6 page = urlopen(url)
# ----> 7 html = page.read().decode("utf-8")
#       8
#       9 # Membuat objek BeautifulSoup
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte

# %%
x = 1
y = 2

x, y = y, x
print('x =', x)
print('y =', y)
# Out:
# x = 2
# y = 1
